# %% [markdown]
# <a href="https://colab.research.google.com/github/adindaarireginadiyah/Tugas_1./blob/main/tugas_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/nutrition.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#         id  calories  proteins   fat  carbohydrate                name  \
# 0        1     280.0       9.2  28.4           0.0                Abon
# 1        2     513.0      23.7  37.0          21.3        Abon haruwan
# 2        3       0.0       0.0   0.2           0.0           Agar-agar
# 3        4      45.0       1.1   0.4          10.8  Akar tonjong segar
# 4        5      37.0       4.4   0.5           3.8       Aletoge segar
# ...    ...       ...       ...   ...           ...                 ...
# 1341  1342      42.0       1.2   0.6           9.3        Wortel Segar
# 1342  1343      37.0       1.0   0.6           8.3        Wortel kukus
# 1343  1344      28.0       0.7   0.5           6.3        Wortel rebus
# 1344  1345     254.0       3.0   1.1          58.1              Yangko
# 1345  1346      52.0       3.3   2.5           4.0             Yoghurt
#
#                                                   image
# 0     https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# ...

# %%
data.head()
# Out:
#    id  calories  proteins   fat  carbohydrate                name  \
# 0   1     280.0       9.2  28.4           0.0                Abon
# 1   2     513.0      23.7  37.0          21.3        Abon haruwan
# 2   3       0.0       0.0   0.2           0.0           Agar-agar
# 3   4      45.0       1.1   0.4          10.8  Akar tonjong segar
# 4   5      37.0       4.4   0.5           3.8       Aletoge segar
#
#                                                image
# 0  https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# 1  https://img-global.cpcdn.com/recipes/cbf330fbd...
# 2  https://res.cloudinary.com/dk0z4ums3/image/upl...
# 3  https://images.tokopedia.net/img/cache/200-squ...
# 4  https://nilaigizi.com/assets/images/produk/pro...

# %%
print(data.dtypes)
# Out:
# id                int64
# calories        float64
# proteins        float64
# fat             float64
# carbohydrate    float64
# name             object
# image            object
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#         id  calories  proteins   fat                name  \
# 0        1     280.0       9.2  28.4                Abon
# 1        2     513.0      23.7  37.0        Abon haruwan
# 2        3       0.0       0.0   0.2           Agar-agar
# 3        4      45.0       1.1   0.4  Akar tonjong segar
# 4        5      37.0       4.4   0.5       Aletoge segar
# ...    ...       ...       ...   ...                 ...
# 1341  1342      42.0       1.2   0.6        Wortel Segar
# 1342  1343      37.0       1.0   0.6        Wortel kukus
# 1343  1344      28.0       0.7   0.5        Wortel rebus
# 1344  1345     254.0       3.0   1.1              Yangko
# 1345  1346      52.0       3.3   2.5             Yoghurt
#
#                                                   image
# 0     https://img-cdn.medkomtek.com/PbrY9X3ignQ8sVuj...
# 1     https://img-global.cpcdn.com/recipes/cbf330fbd...
# 2     https://res.cloudinary.com/dk0z4ums3/image/upl...
# ...

# %%
data.describe()
# Out:
#                 id     calories     proteins          fat  carbohydrate
# count  1346.000000  1346.000000  1346.000000  1346.000000   1346.000000
# mean    673.500000   203.217385    10.001189     7.584027     25.390193
# std     388.701042   163.075430    11.847980    13.733063     32.193054
# min       1.000000     0.000000     0.000000     0.000000      0.000000
# 25%     337.250000    75.000000     1.800000     0.500000      4.525000
# 50%     673.500000   146.000000     5.000000     2.000000     13.300000
# 75%    1009.750000   333.750000    15.000000     8.275000     37.575000
# max    1346.000000   940.000000    83.000000   100.000000    647.000000

# %%
data.loc[:,"calories":].corr()
# Out:
# <ipython-input-14-e995b037242d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"calories":].corr()
#               calories  proteins       fat  carbohydrate
# calories      1.000000  0.354371  0.737809      0.448363
# proteins      0.354371  1.000000  0.225326     -0.133289
# fat           0.737809  0.225326  1.000000     -0.003975
# carbohydrate  0.448363 -0.133289 -0.003975      1.000000

# %%
# @title calories vs proteins

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='calories', y='proteins', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-be30f7d9-91cf-423e-8f16-bcb699c73172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be30f7d9-91cf-423e-8f16-bcb699c73172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "food nutrition"
# Out:
# ...
# ref                                                            title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# joebeachcapital/fast-food                                      Fast Food Nutrition                                40KB  2023-10-17 01:43:33           4541         86  1.0
# niharika41298/nutrition-details-for-most-common-foods          Nutritional Facts for most common foods             6KB  2020-07-25 07:46:38           7708         96  1.0
# shrutisaxena/food-nutrition-dataset                            food nutrition dataset                              1MB  2021-07-29 12:37:15           5964         73  0.9117647
# ...

# %%
# !kaggle datasets download joebeachcapital/fast-food
# Out:
# ...
#   0% 0.00/40.3k [00:00<?, ?B/s]
# 100% 40.3k/40.3k [00:00<00:00, 25.4MB/s]

# %%
# !unzip /content/fast-food.zip
# Out:
# Archive:  /content/fast-food.zip
#   inflating: FastFoodNutritionMenuV2.csv
#   inflating: FastFoodNutritionMenuV3.csv

# %%
pd.read_csv('/content/FastFoodNutritionMenuV2.csv')
# Out:
#          Company                                               Item Calories  \
# 0     McDonald’s                                          Hamburger      250
# 1     McDonald’s                                       Cheeseburger      300
# 2     McDonald’s                                Double Cheeseburger      440
# 3     McDonald’s                                           McDouble      390
# 4     McDonald’s                       Quarter Pounder® with Cheese      510
# ...          ...                                                ...      ...
# 1143   Pizza Hut  Hand Tossed Slices Ultimate Cheese Lover’s® Me...      230
# 1144   Pizza Hut  Hand Tossed Slices Ultimate Cheese Lover’s® Large      310
# 1145   Pizza Hut           Hand Tossed Slices Veggie Lover’s® Small      120
# 1146   Pizza Hut          Hand Tossed Slices Veggie Lover’s® Medium      200
# 1147   Pizza Hut           Hand Tossed Slices Veggie Lover’s® Large      260
#
# ...
